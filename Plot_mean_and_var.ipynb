# %%
import matplotlib.pyplot as plt

def plot_mean_std(mean_data, std_data, filename=None, label=None, newfig=True, color='b'):

    if newfig:
        fig, ax = plt.subplots(1, figsize=(5, 10))
        xvals = np.arange(len(mean_data))
        if label is None:
            ax.plot(xvals, mean_data, color=color)
        else:
            ax.plot(xvals, mean_data, color=color, label=label)
            ax.legend()
        ax.fill_between(
            xvals,
            mean_data - std_data,
            mean_data + std_data,
            color=color,
            alpha=0.25)
        if filename is not None:
            fig.savefig(filename + '.png', dpi=200, bbox_inches='tight')
    else:
        xvals = np.arange(len(mean_data))
        if label is None:
            plt.plot(xvals, mean_data, color=color)
        else:
            plt.plot(xvals, mean_data, color=color, label=label)
            plt.legend()
        plt.fill_between(
            xvals,
            mean_data - std_data,
            mean_data + std_data,
            color=color,
            alpha=0.25)
        if filename is not None:
            fig.savefig(filename + '.png', dpi=200, bbox_inches='tight')
            
            
def plot_mean_std_1(mean_data1, std_data1, mean_data2, std_data2, filename=None, label=None, newfig=True, color='b', y_axis_label='Y'):

    if newfig:
        fig, (ax) = plt.subplots(1, figsize=(10, 10))
        xvals1 = np.arange(len(mean_data1))
        xvals2 = np.arange(len(mean_data2))
        if label is None:
            ax.plot(xvals1, mean_data1, color=color[0])
            ax.plot(xvals2, mean_data2, color=color[1])
        else:
            ax.plot(xvals1, mean_data1, color=color[0], label=label[0])
            ax.plot(xvals2, mean_data2, color=color[1], label=label[1])
            ax.set_xlabel('iterations')
            ax.set_ylabel(y_axis_label)
        ax.fill_between(
            xvals1,
            mean_data1 - std_data1,
            mean_data1 + std_data1,
            color=color[0],
            alpha=0.25)
        ax.fill_between(
            xvals2,
            mean_data2 - std_data2,
            mean_data2 + std_data2,
            color=color[1],
            alpha=0.25)
        ax.legend()
        if filename is not None:
            fig.savefig(filename + '.png', dpi=200, bbox_inches='tight')
    else:
        xvals = np.arange(len(mean_data))
        if label is None:
            plt.plot(xvals, mean_data, color=color)
        else:
            plt.plot(xvals, mean_data, color=color, label=label)
            plt.legend()
        plt.fill_between(
            xvals,
            mean_data - std_data,
            mean_data + std_data,
            color=color,
            alpha=0.25)
        if filename is not None:
            fig.savefig(filename + '.png', dpi=200, bbox_inches='tight')

# %%
import numpy as np

our_rew = np.load('./runs/Ant_pddm_tf_11Sep/rollouts_rewardsPerIter.npy')
our_score = np.load('./runs/Ant_pddm_tf_11Sep/rollouts_scoresPerIter.npy')

orig_rew = np.load('./baseline_tf_code/ant/rollouts_rewardsPerIter.npy')
orig_score = np.load('./baseline_tf_code/ant/rollouts_scoresPerIter.npy')

# plot_mean_std(our_rew[:,0], our_rew[:,1])
# plot_mean_std(orig_rew[:,0], orig_rew[:,1])
plot_mean_std_1(our_rew[:,0], our_rew[:,1], orig_rew[:,0], orig_rew[:,1], label=['pddm_c-51', 'pddm'], color=['b', 'r'], y_axis_label='reward')

plot_mean_std_1(our_score[:,0], our_score[:,1], orig_score[:,0], orig_score[:,1], label=['pddm_c-51', 'pddm'], color=['b', 'r'], y_axis_label='score')

# %% [markdown]
#  ## Pearson Correlation

# %%
import numpy as np
import matplotlib.pyplot as plt

# dist_iter_0 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_0.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_10 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_10.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_20 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_20.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_30 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_30.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_40 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_40.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_50 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_50.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_60 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_60.csv', delimiter=',', skip_header=1)[:,2]
# dist_iter_70 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_70.csv', delimiter=',', skip_header=1)[:,2]

# env_iter_0 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_0.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_10 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_10.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_20 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_20.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_30 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_30.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_40 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_40.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_50 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_50.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_60 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_60.csv', delimiter=',', skip_header=1)[:,2]
# env_iter_70 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_70.csv', delimiter=',', skip_header=1)[:,2]


dist_iter_0 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_0.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_10 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_10.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_20 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_20.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_30 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_30.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_40 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_40.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_50 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_50.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_60 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_60.csv', delimiter=',', skip_header=1)[:-1,2]
dist_iter_70 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_dist_iter_70.csv', delimiter=',', skip_header=1)[:-1,2]

env_iter_0 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_0.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_10 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_10.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_20 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_20.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_30 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_30.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_40 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_40.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_50 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_50.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_60 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_60.csv', delimiter=',', skip_header=1)[:-1,2]
env_iter_70 = np.genfromtxt('./runs/Ant_pddm_tf_11Sep/reward_/run_pddm_tf_test_19Aug-tag-d_reward_env_iter_70.csv', delimiter=',', skip_header=1)[:-1,2]



co_relation_score = []

# print(dist_iter_0.shape)
# print(dist_iter_0[:,2])

# print(np.corrcoef([dist_iter_0, env_iter_0]))
# print(np.corrcoef([dist_iter_0, env_iter_0])[1,0])

co_relation_score.append(np.corrcoef([dist_iter_0, env_iter_0])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_10, env_iter_10])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_20, env_iter_20])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_30, env_iter_30])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_40, env_iter_40])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_50, env_iter_50])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_60, env_iter_60])[1,0])
co_relation_score.append(np.corrcoef([dist_iter_70, env_iter_70])[1,0])

fig, (ax) = plt.subplots(1, figsize=(10, 10))
xvals = np.arange(len(co_relation_score))*10
ax.plot(xvals, co_relation_score)
ax.plot(xvals, co_relation_score, 'bo')
ax.set_xlabel('iterations')
ax.set_ylabel('pearson correlation score')
# Out:
# Text(0, 0.5, 'pearson correlation score')
